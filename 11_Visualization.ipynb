# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('city_day.csv')
data
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
data.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
# 3. Select relevant variables
date_column = "Date"
aqi_column = "AQI"
pollutant_columns = ["PM2.5", "PM10", "CO"]

# %%
plt.figure(figsize=(12, 6))
plt.plot(data[date_column], data[aqi_column], label="AQI", color='b')
plt.xlabel("Date")
plt.ylabel("AQI")
plt.title("AQI Trend Over Time")
plt.legend()
plt.show()

# %%
for pollutant in pollutant_columns:
    plt.figure(figsize=(12, 6))
    plt.plot(data[date_column], data[pollutant])
    plt.title(f'{pollutant} trends over time')
    plt.xlabel('Date')
    plt.ylabel(pollutant)
    plt.grid(True)
    plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(data[date_column], data[aqi_column])
plt.title("AQI Values Across Different Dates")
plt.xlabel("Date")
plt.ylabel("AQI")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# pollutant_data = [data[pollutant] for pollutant in pollutant_columns]
# plt.figure(figsize=(12, 6))
# plt.boxplot(pollutant_data, labels=pollutant_columns)
# plt.title("AQI Distribution by Pollutant Category")
# plt.ylabel("AQI")
# plt.grid(True)
# plt.show()


# 7. Create a violin plot for AQI values by pollutant category
plt.figure(figsize=(12, 6))
sns.violinplot(x="variable", y="value", data=pd.melt(data[pollutant_columns]))
plt.title("AQI Distribution by Pollutant Category")
plt.xlabel("Pollutant")
plt.ylabel("AQI")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.scatter(data["PM2.5"], data["AQI"], alpha=0.5)
plt.title("Scatter Plot: AQI vs. PM2.5")
plt.xlabel("PM2.5")
plt.ylabel("AQI")
plt.grid(True)
plt.show()
